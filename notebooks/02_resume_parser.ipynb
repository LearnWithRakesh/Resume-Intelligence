# %% [markdown]
# ## Setup
# 1. `pip install -r requirements.txt`
# 2. `cp .env.example .env` and set `OPENAI_API_KEY`

# %%
from src.config import load_settings
settings = load_settings()
settings

# %%
from src.agents.resume_parser_agent import parse_resume_text
raw = open("data/samples/sample_resume.txt","r",encoding="utf-8").read()
profile = parse_resume_text(settings, raw)
profile
